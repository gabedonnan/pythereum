# %% [markdown]
# ## A comparison of Pythereum to Web3.py in performance, functionality and ease of use

# %%
import asyncio

import pythereum as pye

from eth_account import Account
from time import time, sleep
from web3 import AsyncWeb3, AsyncHTTPProvider, WebsocketProviderV2
from ens import AsyncENS
from dotenv import dotenv_values
from pprint import pprint

# %%
# Test parameters
iterations = 1_000_000

connection_url = "127.0.0.1:8545"
external_connection_url = dotenv_values("../.env")["TEST_WS"]
http_external_url = external_connection_url.replace("wss://", "https://")

w3 = AsyncWeb3(AsyncHTTPProvider(http_external_url))
w3_local = AsyncWeb3(AsyncHTTPProvider(f"http://{connection_url}"))

# %%
nsum = 0
pyetimesum = 0
w3timesum = 0


for n in range(100, 5100, 1000):
    t0 = time()

    async with pye.EthRPC(f"ws://{connection_url}") as erpc:
        await erpc.get_block_by_number(
            list(range(n)),
            [True for i in range(n)]
        )
    print(f"pythereum processed {n} get_block_by_number requests in {(pyetime := time() - t0)} seconds")
    print(f"that's {n / pyetime} requests per second!")

    t0 = time()

    for result in asyncio.as_completed(
            [w3_local.eth.get_block(num, True) for num in range(n)]
        ):
        try:
            await result
        except:
            pass

    print(f"Web3.py processed {n} get_block_by_number requests in {(w3time := time() - t0)} seconds")
    print(f"that's {n / w3time} requests per second")
    
    nsum += n
    pyetimesum += pyetime
    w3timesum += w3time
    
print(f"\nOn average pythereum processed {nsum / pyetimesum} requests per second and web3.py processed {nsum / w3timesum} requests per second\nThat's a {w3timesum/pyetimesum} times speedup!")
# Out:
# pythereum processed 100 get_block_by_number requests in 0.02303791046142578 seconds
# that's 4340.671440990189 requests per second!
# Web3.py processed 100 get_block_by_number requests in 0.04408693313598633 seconds
# that's 2268.2457791189418 requests per second
# pythereum processed 1100 get_block_by_number requests in 0.19179439544677734 seconds
# that's 5735.308362048819 requests per second!
# Web3.py processed 1100 get_block_by_number requests in 0.40035295486450195 seconds
# that's 2747.5755745884057 requests per second
# pythereum processed 2100 get_block_by_number requests in 0.26764893531799316 seconds
# that's 7846.098836541211 requests per second!
# Web3.py processed 2100 get_block_by_number requests in 0.7279794216156006 seconds
# that's 2884.696926376685 requests per second
# pythereum processed 3100 get_block_by_number requests in 0.47873473167419434 seconds
# that's 6475.402336402287 requests per second!
# Web3.py processed 3100 get_block_by_number requests in 1.1260836124420166 seconds
# that's 2752.903928046127 requests per second
# pythereum processed 4100 get_block_by_number requests in 0.5778670310974121 seconds
# that's 7095.057823620423 requests per second!
# Web3.py processed 4100 get_block_by_number requests in 1.5188186168670654 seconds
# that's 2699.4665159275255 requests per second
#
# On average pythereum processed 6822.244136752867 requests per second and web3.py processed 2750.61974552881 requests per second
# That's a 2.4802570940031123 times speedup!

# %% [markdown]
# ### Individual call speeds (Not making use of batching)

# %%
t0 = time()

num_calls = 100

async with pye.EthRPC(external_connection_url, use_socket_pool=False) as erpc:
    async with asyncio.TaskGroup() as tg:
        for i in range(num_calls):
            tg.create_task(erpc.get_block_number())
            
print((pyetime_individual := time() - t0))
t0 = time()

# Since web3.py is single-socketed it will raise too many requests errors on many free endpoints with higher than 80 task pairs
async with asyncio.TaskGroup() as tg:
    for i in range(num_calls):
        tg.create_task(w3.eth.get_block_number())
            
print((w3time_individual := time() - t0))
t0 = time()

async with AsyncWeb3.persistent_websocket(WebsocketProviderV2(external_connection_url)) as ws:
    async with asyncio.TaskGroup() as tg:
        for i in range(num_calls):
            tg.create_task(ws.eth.get_block_number())
    
print((w3time_websocket_individual := time() - t0))

print(f"When calling {num_calls} functions in the same way using task groups, Pythereum is found to be {w3time_individual / pyetime_individual} times faster than Web3.py")
print(f"Additionally it is {w3time_websocket_individual / pyetime_individual} times faster than a websocketed version of Web3.py")
print("From running this many times Pythereum averages a 2.5-4x speedup over Web3.py")
# Out:
# 1.4234800338745117
# 2.466068744659424
# 2.844428539276123
# When calling 100 functions in the same way using task groups, Pythereum is found to be 1.7324224337359568 times faster than Web3.py
# Additionally it is 1.998221591864545 times faster than a websocketed version of Web3.py
# From running this many times Pythereum averages a 2.5-4x speedup over Web3.py

# %% [markdown]
# ### More intensive tests, with higher iteration numbers, both processed using asyncio.gather

# %%
t0 = time()

# Pythereum using batch calls

async with pye.EthRPC(f"ws://{connection_url}", pool_size=10) as erpc:
    await asyncio.gather(*(
        erpc.get_block_by_number(
            [i for i in range(start, start+1000)], 
            [True for i in range(start, start+1000)]
        ) for start in range(0, iterations, 1000)
    ))
print(f"Pythereum made {iterations} requests in {(pyetime_intense := time() - t0)} seconds")
# Out:
# Pythereum made 1000000 requests in 134.84792470932007 seconds

# %%
t0 = time()
# Web3 does not natively support batch RPC calls

async def blknum(num):
    # Defined to handle errors as Web3.py does not like empty returns
    # Yes it is better to have an exception type, no it doesnt really matter
    try:
        await w3_local.eth.get_block(num, True)
    except:
        pass

await asyncio.gather(*(blknum(num) for num in range(iterations)))
print(f"Web3.py made {iterations} requests in {(w3time_intense := time() - t0)} seconds")
# Out:
# Web3.py made 1000000 requests in 377.48311281204224 seconds

# %%
print(f"Pythereum is able to process transactions {w3time_intense / pyetime_intense} times faster than Web3.py in intense testing,\nWith Pythereum processing {iterations / pyetime_intense} transactions per second,\nand Web3 processing {iterations / w3time_intense} transactions per second")
# Out:
# Pythereum is able to process transactions 2.79932459936443 times faster than Web3.py in intense testing,
# With Pythereum processing 7415.7611409713045 transactions per second,
# and Web3 processing 2649.1251292025972 transactions per second

# %% [markdown]
# ### Subscriptions

# %%
# Pythereum subscription implementation, an infinite loop which gets block headers whenever new blocks are created

# Web3.py has no native implementation of subscriptions, and as such would have to be coded from scratch

# Items will be in the form of a Block object, with each json value converted into an appropriate data type

# Running this on localhost will result in nothing happening as no blocks are being created!

async with pye.EthRPC(external_connection_url) as erpc:
    async with erpc.subscribe(pye.SubscriptionType.new_heads) as sc:
        async for item in sc.recv():
            pprint(item)
# Out:
# Block(difficulty=0,
#       extra_data=HexStr('0x7273796e632d6275696c6465722e78797a'),
#       gas_limit=30000000,
#       gas_used=12199687,
#       hash=HexStr('0x537ee530093d60fabe3120d2222f839653d0cfde31ea0d94686be44feade76de'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x1f9090aae28b8a3dceadf281b0f12828e676c326'),
#       mix_hash=HexStr('0x20bfcb2fd0b52112a27939675cd5e74c17ca0afd2891dc91a2e383c93fc21413'),
#       nonce=0,
#       number=18415340,
#       parent_hash=HexStr('0x02feed3c46931582c8b6356c23598de1038c357340b8033235a26f6df674bfce'),
#       receipts_root=HexStr('0x55e34a570e51adc290657eb71d0055406a75c6bb4ae2c01497a6418bebbe3765'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=67038,
#       state_root=HexStr('0x1efd1a2c5672b1d4c5e61fc9ced2e40415428503d887f2990fa9c7b8957c3250'),
#       timestamp=HexStr('0x6536d6d7'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0xfefd2e339002d02764826bbf043599d4c39b219c636b4d2c777c5fb98869173a'),
#       uncles=None,
#       base_fee_per_gas=36758648637)
# Block(difficulty=0,
#       extra_data=HexStr('0x7273796e632d6275696c6465722e78797a'),
#       gas_limit=30000000,
#       gas_used=15401284,
#       hash=HexStr('0xc523fea873b836077e715cf1f97d0c587eb03a345cf974045b6bb8bdf5f41122'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x1f9090aae28b8a3dceadf281b0f12828e676c326'),
#       mix_hash=HexStr('0x0e49ae12f538f29f230747fc1f327d1fda1c534e085049a0a1946a86dcc0a11e'),
#       nonce=0,
#       number=18415341,
#       parent_hash=HexStr('0x537ee530093d60fabe3120d2222f839653d0cfde31ea0d94686be44feade76de'),
#       receipts_root=HexStr('0x36bdba732876218b255018207aa605f11a4906191f12b72b86f6a78babf38af0'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=297497,
#       state_root=HexStr('0xdad9ee0c33758f53b05d52aeef04b78aa7a5f4ec8e62f433919f95d381c79fab'),
#       timestamp=HexStr('0x6536d6e3'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0x98c0d509bd5d08b335dd4332587ea49633709e2c45424129db5271f0d717fab1'),
#       uncles=None,
#       base_fee_per_gas=35900850957)
# Block(difficulty=0,
#       extra_data=HexStr('0x546974616e2028746974616e6275696c6465722e78797a29'),
#       gas_limit=29970705,
#       gas_used=10735593,
#       hash=HexStr('0xc362707e24e0c4519fc54af0d5c5b2b2508e94973636cb180059ef490315571a'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97'),
#       mix_hash=HexStr('0x07e678081a7f5557d8c7a9b05512f23226a6b0747d517d26505712b77651eab3'),
#       nonce=0,
#       number=18415342,
#       parent_hash=HexStr('0xc523fea873b836077e715cf1f97d0c587eb03a345cf974045b6bb8bdf5f41122'),
#       receipts_root=HexStr('0xd2490d6bb2a43324b18c679b1b2f0ffc903697f1c19d7f4363ac2985a19b903c'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=120855,
#       state_root=HexStr('0xf0fe110c4fbe04c01a85fb9d188fef833fb90b41d55eea9cd3cf29c251dd29fa'),
#       timestamp=HexStr('0x6536d6ef'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0x655c0d1b45ca038fff4ab3ae1de231a55d6c34ab996561391b7e18ad42fa4a40'),
#       uncles=None,
#       base_fee_per_gas=36020904599)
# Block(difficulty=0,
#       extra_data=HexStr('0x7273796e632d6275696c6465722e78797a'),
#       gas_limit=29999972,
#       gas_used=17839218,
#       hash=HexStr('0x3b77a8466b43425b1b0a02e42bba276a507ee5fff9bea279b5d3b66cd4818a72'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x1f9090aae28b8a3dceadf281b0f12828e676c326'),
#       mix_hash=HexStr('0xbcd0d70d8094ebc72ffa92ae571e8cd7cd89fc411024f0362d4fdd670a72a82d'),
#       nonce=0,
#       number=18415343,
#       parent_hash=HexStr('0xc362707e24e0c4519fc54af0d5c5b2b2508e94973636cb180059ef490315571a'),
#       receipts_root=HexStr('0x01a5a9769e5c86163391c896163142163f01fb1fed5df343b199c0e12d74674c'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=133956,
#       state_root=HexStr('0x519d6438a73d6b32f76109dffb62080370a3e4c2649cc00050fbd7ae84dab46e'),
#       timestamp=HexStr('0x6536d6fb'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0x68ea0035da6b73fe74bf3e1cb10975beac7797f5680791fb13f9a3bfcea25417'),
#       uncles=None,
#       base_fee_per_gas=34743989620)
# Block(difficulty=0,
#       extra_data=HexStr('0x7273796e632d6275696c6465722e78797a'),
#       gas_limit=30000000,
#       gas_used=12666738,
#       hash=HexStr('0x6b427871d5db3db6023c6a254e6957fe58e089c10f0f3568b779f1746ec44c55'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x1f9090aae28b8a3dceadf281b0f12828e676c326'),
#       mix_hash=HexStr('0xa684f50ee9c12846873ebc25ceb6deeb80713df3b711580794c2dc82d6a77086'),
#       nonce=0,
#       number=18415344,
#       parent_hash=HexStr('0x3b77a8466b43425b1b0a02e42bba276a507ee5fff9bea279b5d3b66cd4818a72'),
#       receipts_root=HexStr('0xe1640acbf7300a1d14109fe5c20fd4c2310a98ec197632c7497f676ec41845db'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=62323,
#       state_root=HexStr('0x2ff992c18f4e43d7f0edd74246ed4097816e024c6c965255b7366350aade4df8'),
#       timestamp=HexStr('0x6536d707'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0xd686cc1fa5e9e2ddcb5dd77ee8c4b9c1ca77a9235876af45a544316612e7a729'),
#       uncles=None,
#       base_fee_per_gas=35566042446)
# Block(difficulty=0,
#       extra_data=HexStr('0xd883010d04846765746888676f312e32312e33856c696e7578'),
#       gas_limit=30000000,
#       gas_used=6915804,
#       hash=HexStr('0x4650aa3c7aa45ed229024fef88d1bfdbafc53efeac5c9c15d4b191ad167de43e'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x3086723a2bd5b073ee28ff51a1eeadde8d011fcc'),
#       mix_hash=HexStr('0x44a54599a1472ce3abe5d1df0079be00730378fcec6a71d3ffb8f21d24eb5e59'),
#       nonce=0,
#       number=18415345,
#       parent_hash=HexStr('0x6b427871d5db3db6023c6a254e6957fe58e089c10f0f3568b779f1746ec44c55'),
#       receipts_root=HexStr('0x948e2c80b63cb35baed969fbd35489476ae51227304c2fb34655d0e8607a10b8'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=53984,
#       state_root=HexStr('0xba5dec4f323b99702af78d2f22fe0802d900272c3ef4dbfaec1a4dc8a4526e7e'),
#       timestamp=HexStr('0x6536d713'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0xc1fd068e63e998db725adf72a25ea116734bdfdba4af1bd96eee398225248469'),
#       uncles=None,
#       base_fee_per_gas=34874501652)
# Block(difficulty=0,
#       extra_data=HexStr('0x47616d626974204c616273202868747470733a2f2f676d6269742e636f29'),
#       gas_limit=30000000,
#       gas_used=17301091,
#       hash=HexStr('0x71d2e24813f5a6fbfd2f97220750a33a29eb77fe7084229a4ee0eec65ca3c774'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x388c818ca8b9251b393131c08a736a67ccb19297'),
#       mix_hash=HexStr('0x2fa0e340ab2f22a3a1dfba31ea1e707054c289dbca44d40485f07de38bda6c60'),
#       nonce=0,
#       number=18415346,
#       parent_hash=HexStr('0x4650aa3c7aa45ed229024fef88d1bfdbafc53efeac5c9c15d4b191ad167de43e'),
#       receipts_root=HexStr('0x2f0f2a2f6b9ad010a1efd323a97a5fe7a9fe838bbceb81c74488282f5b187783'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=143435,
#       state_root=HexStr('0xad98e10af2b98e09185ea15ce11b29519fd74842efa0fdeef0428442c8d7f206'),
#       timestamp=HexStr('0x6536d71f'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0x3b45faa97fcfe179739be8864f797afccbacc437555b06b5caa1b555e24c53c2'),
#       uncles=None,
#       base_fee_per_gas=32525065763)
# Block(difficulty=0,
#       extra_data=HexStr('0x47616d626974204c616273202868747470733a2f2f676d6269742e636f29'),
#       gas_limit=30000000,
#       gas_used=18830161,
#       hash=HexStr('0xf4d7ad51e43303fb08679927c3a324746cd7f7dbc811567e08cde2b87625d39c'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x0aa8ebb6ad5a8e499e550ae2c461197624c6e667'),
#       mix_hash=HexStr('0x1d823275c47f4462602dcb34b22ee568bf6232d4e31d7d8115e6e5c1277bf07b'),
#       nonce=0,
#       number=18415347,
#       parent_hash=HexStr('0x71d2e24813f5a6fbfd2f97220750a33a29eb77fe7084229a4ee0eec65ca3c774'),
#       receipts_root=HexStr('0x88278e7536092c7278486416b610dc5baa8c97a847cd3617b846db71df6ab727'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=190662,
#       state_root=HexStr('0x3f9783920a9ad78258cd32e93aea5d7622d1cf2742cd622b5ff7d493fe4e2182'),
#       timestamp=HexStr('0x6536d72b'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0xe2a51ca93afd3030b704096eae38c8e154124e01a2dbc7e806b84a8e210e14e7'),
#       uncles=None,
#       base_fee_per_gas=33148758563)
# Block(difficulty=0,
#       extra_data=HexStr('0x6e666163746f7269616c2e78797a'),
#       gas_limit=30000000,
#       gas_used=24025012,
#       hash=HexStr('0x9bead1d14cc3bb0eb2553c3b52f2826873b7a23636e9aa0979eaef70abf1e34e'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x3b7faec3181114a99c243608bc822c5436441fff'),
#       mix_hash=HexStr('0x39b6f1b8ad629a8cdea128a96b7984aff8686b70cf52e6031cdbb2526898b7ff'),
#       nonce=0,
#       number=18415348,
#       parent_hash=HexStr('0xf4d7ad51e43303fb08679927c3a324746cd7f7dbc811567e08cde2b87625d39c'),
#       receipts_root=HexStr('0x57ae49e27ba41d33f36a8ffe253c53a25a181747dbda937fe4b3136e31b2c2ae'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=132481,
#       state_root=HexStr('0x6e34686d9bea1e4a93c164e9e96e11e25d4424ef4c8ebb969d74762265f9e506'),
#       timestamp=HexStr('0x6536d737'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0xb1d8db00172d2dccbbb9897d3ee20953e8945e345e6451c86a748fab67325e7f'),
#       uncles=None,
#       base_fee_per_gas=34206800915)
# Block(difficulty=0,
#       extra_data=HexStr('0x6265617665726275696c642e6f7267'),
#       gas_limit=30000000,
#       gas_used=29981181,
#       hash=HexStr('0x1cf8aeae09dc070491714dbe569a081307a72aaf12dc64304d58247991965778'),
#       logs_bloom=HexStr('...'),
#       miner=HexStr('0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5'),
#       mix_hash=HexStr('0xe2bcda48dd15812c2d2e38a56d9a93707fc53e243acc957c651bd64356ffd277'),
#       nonce=0,
#       number=18415349,
#       parent_hash=HexStr('0x9bead1d14cc3bb0eb2553c3b52f2826873b7a23636e9aa0979eaef70abf1e34e'),
#       receipts_root=HexStr('0x3ef822ce0fe92d14b50dada342434bc0954fdd71ef7a4821e98681ea5d83688a'),
#       sha3_uncles=HexStr('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#       size=136482,
#       state_root=HexStr('0x1aca64557b04f8745bce18f59b72633fc9868c7e16c721c211bfda9a2faf9009'),
#       timestamp=HexStr('0x6536d743'),
#       total_difficulty=None,
#       transactions=None,
#       transactions_root=HexStr('0x33fb11767550dfc8e1c36cd304e57e738be1904c87f7981034aeb1560efb9bf5'),
#       uncles=None,
#       base_fee_per_gas=36779440821)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[11], line 11
#       9 async with pye.EthRPC(external_connection_url) as erpc:
#      10     async with erpc.subscribe(pye.SubscriptionType.new_heads) as sc:
# ---> 11         async for item in sc.recv():
#      12             pprint(item)
#
# File ~/anaconda3/lib/python3.11/site-packages/pythereum/rpc.py:91, in Subscription.recv(self)
#      87 """
#      88 infinite async generator function which will yield new information retrieved from a websocket
#      89 """
#      90 while True:
# ---> 91     res = await self.socket.recv()
#      92     res = parse_results(res, is_subscription=True)
#      93     yield self.decode_function(res)
#
# File ~/anaconda3/lib/python3.11/site-packages/websockets/legacy/protocol.py:551, in WebSocketCommonProtocol.recv(self)
#     547 self._pop_message_waiter = pop_message_waiter
#     548 try:
#     549     # If asyncio.wait() is canceled, it doesn't cancel
#     550     # pop_message_waiter and self.transfer_data_task.
# --> 551     await asyncio.wait(
#     552         [pop_message_waiter, self.transfer_data_task],
#     553         return_when=asyncio.FIRST_COMPLETED,
#     554         **loop_if_py_lt_38(self.loop),
#     555     )
#     556 finally:
#     557     self._pop_message_waiter = None
#
# File ~/anaconda3/lib/python3.11/asyncio/tasks.py:418, in wait(fs, timeout, return_when)
#     415     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     417 loop = events.get_running_loop()
# --> 418 return await _wait(fs, timeout, return_when, loop)
#
# File ~/anaconda3/lib/python3.11/asyncio/tasks.py:525, in _wait(fs, timeout, return_when, loop)
#     522     f.add_done_callback(_on_completion)
#     524 try:
# --> 525     await waiter
#     526 finally:
#     527     if timeout_handle is not None:
#
# CancelledError:

# %% [markdown]
# ###
